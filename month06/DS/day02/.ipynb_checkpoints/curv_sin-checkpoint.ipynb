# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['font.sans-serif'] = 'SimHei' ## 设置中文显示

plt.rcParams['axes.unicode_minus'] = False ## 正常显示负号

# %%
# 创建画布 长 10*dpi, 宽 8*dpi
fig = plt.figure(figsize=(10, 8))
x_list = np.linspace(0, 4*np.pi, 120)
plt.plot(x_list, np.sin(x_list))
plt.xlabel(s='x', fontsize=18)
plt.ylabel(s='y', fontsize=18)
plt.title(s='sin曲线', fontsize=18)
plt.xlim(0)
plt.legend(labels=['y=sin(x)'])
plt.show()

# %%
import matplotlib as mpl
mpl.get_cachedir()
# Out:
# '/home/tarena/.cache/matplotlib'
